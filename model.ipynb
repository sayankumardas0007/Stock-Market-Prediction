# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("data.csv")
# print(data)
data.head()
# Out:
#         open       high        low      close   tomorrow
# 0  17.799999  18.219000  17.500000  17.760000  17.660000
# 1  17.700001  18.309999  17.620001  17.660000  16.950001
# 2  17.580000  17.799999  16.910000  16.950001  16.170000
# 3  16.650000  16.879999  16.139999  16.170000  15.710000
# 4  16.219999  16.290001  15.630000  15.710000  15.860000

# %%
data.shape
# Out:
# (7780, 5)

# %%
data.isnull().sum()
# Out:
# open        0
# high        0
# low         0
# close       0
# tomorrow    0
# dtype: int64

# %%
x = data.drop(columns='tomorrow', axis=1)
y = data['tomorrow']

# %%
x
# Out:
#            open       high        low      close
# 0     17.799999  18.219000  17.500000  17.760000
# 1     17.700001  18.309999  17.620001  17.660000
# 2     17.580000  17.799999  16.910000  16.950001
# 3     16.650000  16.879999  16.139999  16.170000
# 4     16.219999  16.290001  15.630000  15.710000
# ...         ...        ...        ...        ...
# 7775  23.330000  23.379999  23.049999  23.299999
# 7776  23.250000  23.540001  23.250000  23.290001
# 7777  23.350000  23.610001  23.250000  23.350000
# 7778  23.450001  23.570000  23.219999  23.350000
# 7779  23.330000  23.740000  23.330000  23.610001
#
# [7780 rows x 4 columns]

# %%
y
# Out:
# 0       17.660000
# 1       16.950001
# 2       16.170000
# 3       15.710000
# 4       15.860000
#           ...
# 7775    23.290001
# 7776    23.350000
# 7777    23.350000
# 7778    23.610001
# 7779    23.610001
# Name: tomorrow, Length: 7780, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 0.9169659137446993

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 10.655741651309683
